# %%
import mwr
import mrcfile
import torch

sigma_noise = 0.01
plotFlag    = 1 # % set to 1 to observe processing in real time

#% Launch processing:
Vin = torch.load("./emb_sample.pt")
wedge = torch.load("./emb_mask.pt")
Vin = Vin[Vin.shape[0] //2 - 50 : Vin.shape[0] //2 + 50,
            Vin.shape[1] //2 - 50: Vin.shape[1]//2 + 50,
            Vin.shape[2] //2 - 50: Vin.shape[2] //2 + 50]

wedge = wedge[wedge.shape[0] //2 - 50 : wedge.shape[0] //2 + 50,
            wedge.shape[1] //2 - 50: wedge.shape[1]//2 + 50,
            wedge.shape[2] //2 - 50: wedge.shape[2] //2 + 50]
Vout = mwr.mwr(Vin, sigma_noise, wedge, plotFlag, T=30, Tb = 10)
torch.save(Vout, "./mwr.pt")
# Out:
# Iteration 1 / 30 ...
# Iteration 2 / 30 ...
# Iteration 3 / 30 ...
# Iteration 4 / 30 ...
# Iteration 5 / 30 ...
# Iteration 6 / 30 ...
# Iteration 7 / 30 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#      11 Vin = Vin[Vin.shape[0] //2 - 50 : Vin.shape[0] //2 + 50,
#      12             Vin.shape[1] //2 - 50: Vin.shape[1]//2 + 50,
#      13             Vin.shape[2] //2 - 50: Vin.shape[2] //2 + 50]
#      15 wedge = wedge[wedge.shape[0] //2 - 50 : wedge.shape[0] //2 + 50,
#      16             wedge.shape[1] //2 - 50: wedge.shape[1]//2 + 50,
#      17             wedge.shape[2] //2 - 50: wedge.shape[2] //2 + 50]
# ---> 18 Vout = mwr.mwr(Vin, sigma_noise, wedge, plotFlag, T=30, Tb = 10)
#      19 torch.save(Vout, "./mwr.pt")
#
# File ~/Desktop/SULI/py_cryo_MCMC/mwr.py:48, in mwr(Vin, sigma_noise, wedge, plot_flag, T, Tb, beta)
#      45 z = torch.real(torch.fft.ifftn(z_spectrum))
#      47 # Denoise
# ---> 48 z = denoise(z, sigma_excite)
#      49 z = perdecomp3D.perdecomp3D(z)
#      51 # Compute energies
#
# File ~/Desktop/SULI/py_cryo_MCMC/mwr.py:98, in denoise(dataIN, sigma_noise)
#      96 profile = BM4DProfileLC()
#      97 #profile = bm4d.BM4DProfile() #normal profile
# ---> 98 return torch.Tensor(bm4d.bm4d(dataIN, sigma_noise, profile, bm4d.BM4DStages.HARD_THRESHOLDING))
#
# File ~/miniconda3/envs/envupdate/lib/python3.11/site-packages/bm4d/__init__.py:217, in bm4d(z, sigma_psd, profile, stage_arg, blockmatches)
#     213 t_forward, t_inverse, hadper_trans_single_den, \
#     214     inverse_hadper_trans_single_den, wwin3d = _get_transforms(pro, True)
#     216 # Call the actual hard-thresholding step with the acquired parameters
# --> 217 y_hat, bm_out_ht = ht_fn(z, psd_blur, pro, t_forward, t_inverse, qshifts, hadper_trans_single_den,
#     218                         inverse_hadper_trans_single_den, wwin3d, blockmatches=bm_in_ht)
#     220 # Residual denoising, HT
#     221 if pro.denoise_residual:
#
# File ~/miniconda3/envs/envupdate/lib/python3.11/site-packages/bm4d/bm4d_ctypes.py:609, in bm4d_ht(z, psd, pro, t_forward, t_inverse, qshifts, hadper_trans_single_den, inverse_hadper_trans_single_den, wwin3d, refilter, blockmatches)
#     606 c_psd = conv_to_array(np.ascontiguousarray(psd.flatten(), dtype=np.float32), ctype=ctypes.c_float)
#     607 c_est = conv_to_array(np.ascontiguousarray(res.flatten(), dtype=np.float32), ctype=ctypes.c_float)
# --> 609 func_ht(c_z, c_psd, params, transforms, c_est,
#     610         ctypes.byref(matchtables) if matchtables is not None else matchtables)
#     612 for i in range(z_shape[0]):
#     613     for j in range(z_shape[1]):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.imshow(Vin[50,:,:])
plt.show()
plt.imshow(Vin[:,50,:])
plt.show()
plt.imshow(Vin[:,:,50])
plt.show()

# %%
plt.imshow(wedge[50,:,:])
plt.colorbar()
plt.show()
plt.imshow(wedge[:,50,:])
plt.colorbar()

plt.show()
plt.imshow(wedge[:,:,50])
plt.colorbar()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.imshow(wedge[50,:,:])
#       2 plt.colorbar()
#       3 plt.show()
#
# NameError: name 'plt' is not defined
